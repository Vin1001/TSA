# %%
from mypackages.predictor import stock_predictor as spr
import matplotlib.pyplot as plt
from mypackages.imager import stock_imager as sim
plt.style.use(style='seaborn-v0_8')
# %matplotlib inline

# %%
stock = spr('adaniports.ns', per='10d', intrvl='15m')

# %%
stock.lags(24)
# Out:
#                                     0            1            2            3   \
# Datetime
# 2024-01-24 15:00:00+05:30  1121.000000  1123.000000  1129.400024  1128.300049
# 2024-01-24 15:15:00+05:30  1123.000000  1129.400024  1128.300049  1129.750000
# 2024-01-25 09:15:00+05:30  1129.400024  1128.300049  1129.750000  1125.250000
#
#                                     4            5            6            7   \
# Datetime
# 2024-01-24 15:00:00+05:30  1129.750000  1125.250000  1122.949951  1121.550049
# 2024-01-24 15:15:00+05:30  1125.250000  1122.949951  1121.550049  1113.050049
# 2024-01-25 09:15:00+05:30  1122.949951  1121.550049  1113.050049  1113.500000
#
#                                     8            9   ...           15  \
# Datetime                                             ...
# 2024-01-24 15:00:00+05:30  1113.050049  1113.500000  ...  1122.250000
# 2024-01-24 15:15:00+05:30  1113.500000  1116.150024  ...  1120.400024
# ...

# %%
print(stock.dev)
stock.fit(80)
# Out:
# 0.3312024625126562
# mean:2.7117018176286796,std:3.8566063748459367
# 3.799152246372614

# %%
stock.plot_predict()

# %%
stock.forecast(t=-3, d=3, k=1, look=3)
# Out:
# IF 1135.18 THEN:  0.63,up:1138.01,mean:1134.21,low:1130.41 d(0)
#
# IF  1137.7 THEN:  0.69,up:1140.08,mean:1136.28,low:1132.48 d(0)
#
# IF 1136.44 THEN:  0.68,up:1138.85,mean:1135.05,low:1131.25 d(1)
#
# IF  1137.7 THEN:  0.67,up:1140.19,mean:1136.39,low:1132.59 d(0)
#
# IF 1140.22 THEN:  0.73,up:1142.26,mean:1138.46,low:1134.66 d(0)
#
# IF 1138.96 THEN:  0.74,up:1140.92,mean:1137.12,low:1133.32 d(1)
#
# IF  1137.7 THEN:  0.63,up:1140.48,mean:1136.68,low:1132.88 d(2)
#
# 0.6340717445811308
#
# [ 0.63, up: 1140.48, mean: 1136.68, low: 1132.88],  1137.7
# [ 0.69, up: 1139.05, mean: 1135.25, low: 1131.45],  1137.7
# [ 0.63, up: 1138.07, mean: 1134.27, low: 1130.47],  1137.7

# %%
stock.df1.tail(10)
# Out:
#                                  Close
# Datetime
# 2024-01-25 13:00:00+05:30  1130.699951
# 2024-01-25 13:15:00+05:30  1129.199951
# 2024-01-25 13:30:00+05:30  1131.900024
# 2024-01-25 13:45:00+05:30  1128.250000
# 2024-01-25 14:00:00+05:30  1133.800049
# 2024-01-25 14:15:00+05:30  1131.800049
# 2024-01-25 14:30:00+05:30  1128.750000
# 2024-01-25 14:45:00+05:30  1137.699951
# 2024-01-25 15:00:00+05:30  1147.099976
# 2024-01-25 15:15:00+05:30  1151.000000

# %%
tcs = spr('tcs.ns', per='1y', intrvl= '1d', cols=['Close'])

# %%
tcs.lags(26)
# Out:
#                                     0            1            2            3   \
# Date
# 2023-12-11 00:00:00+05:30  3626.097656  3655.163086  3576.975342  3650.335449
# 2023-12-12 00:00:00+05:30  3655.163086  3576.975342  3650.335449  3843.191895
# 2023-12-13 00:00:00+05:30  3576.975342  3650.335449  3843.191895  3841.400146
#
#                                     4            5            6            7   \
# Date
# 2023-12-11 00:00:00+05:30  3843.191895  3841.400146  3798.598389  3762.615234
# 2023-12-12 00:00:00+05:30  3841.400146  3798.598389  3762.615234  3770.030762
# 2023-12-13 00:00:00+05:30  3798.598389  3762.615234  3770.030762  3806.362549
#
#                                     8            9   ...           17  \
# Date                                                 ...
# 2023-12-11 00:00:00+05:30  3770.030762  3806.362549  ...  3649.887451
# 2023-12-12 00:00:00+05:30  3806.362549  3778.043701  ...  3720.659424
# ...

# %%
print(tcs.dev)
tcs.fit(85)
# Out:
# 0.3519093804266209
# mean:27.197075506763237,std:24.87455496084199
# 47.955016060810294

# %%
tcs.plot_predict()

# %%
tcs.forecast(t=-3, d=3, k=1, look=3)
# Out:
# IF 3832.93 THEN:   0.8,up:3852.13,mean:3804.17,low:3756.22 d(0)
#
# IF 3866.68 THEN:   0.8,up:3885.82,mean:3837.86,low:3789.91 d(0)
#
# IF 3849.81 THEN:  0.98,up:3848.02,mean:3800.06,low:3752.11 d(1)
#
# IF 3866.68 THEN:  0.82,up:3884.18,mean:3836.22,low:3788.27 d(0)
#
# IF 3900.43 THEN:  0.82,up:3917.87,mean:3869.91,low:3821.96 d(0)
#
# IF 3883.56 THEN:  0.98,up:3881.71,mean:3833.75,low: 3785.8 d(1)
#
# IF 3866.68 THEN:  0.65,up:3900.57,mean:3852.61,low:3804.66 d(2)
#
# 0.646691852794324
#
# [ 0.65, up: 3900.57, mean: 3852.61, low: 3804.66], 3866.68
# [ 0.98, up: 3850.82, mean: 3802.86, low: 3754.91], 3866.68
# [  0.8, up: 3821.98, mean: 3774.03, low: 3726.07], 3866.68

# %%
tcs.df1.tail(10)
# Out:
#                                  Close
# Date
# 2024-01-08 00:00:00+05:30  3661.334473
# 2024-01-09 00:00:00+05:30  3672.880859
# 2024-01-10 00:00:00+05:30  3695.924316
# 2024-01-11 00:00:00+05:30  3718.320557
# 2024-01-12 00:00:00+05:30  3864.891357
# 2024-01-15 00:00:00+05:30  3885.794434
# 2024-01-16 00:00:00+05:30  3843.490479
# 2024-01-17 00:00:00+05:30  3866.683105
# 2024-01-18 00:00:00+05:30  3884.600098
# 2024-01-19 00:00:00+05:30  3943.050049
